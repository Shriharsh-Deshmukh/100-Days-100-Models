# %% [markdown]
# <a href="https://colab.research.google.com/github/Shriharsh-Deshmukh/100-Days-100-Models/blob/main/(Pr_3)patient_ai_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **AI Model Building**

# %% [markdown]
# ## **import libraries and dataset**

# %%
import pandas as pd

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/Shriharsh-Deshmukh/100-Days-100-Models/refs/heads/main/Datasets/3.patients_data.csv')

# %%
dataset
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0                      1        17.99         10.38          122.80
# 1                      1        20.57         17.77          132.90
# 2                      1        19.69         21.25          130.00
# 3                      1        11.42         20.38           77.58
# 4                      1        20.29         14.34          135.10
# ..                   ...          ...           ...             ...
# 564                    1        21.56         22.39          142.00
# 565                    1        20.13         28.25          131.20
# 566                    1        16.60         28.08          108.30
# 567                    1        20.60         29.33          140.10
# 568                    0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# ## **assign x and y values**

# %%
x = dataset.drop(columns=["diagnosis(1=m, 0=b)"])

# %%
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
y = dataset["diagnosis(1=m, 0=b)"]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis(1=m, 0=b), Length: 569, dtype: int64

# %% [markdown]
# ## **Data Splitting process**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 68         9.029         17.33           58.79      250.5          0.10660
# 181       21.090         26.57          142.70     1311.0          0.11410
# 63         9.173         13.86           59.20      260.9          0.07721
# 248       10.650         25.22           68.01      347.0          0.09657
# 60        10.170         14.88           64.55      311.9          0.11340
# ..           ...           ...             ...        ...              ...
# 71         8.888         14.64           58.79      244.0          0.09783
# 106       11.640         18.33           75.17      412.5          0.11420
# 270       14.290         16.82           90.30      632.6          0.06429
# 435       13.980         19.62           91.12      599.5          0.10600
# 102       12.180         20.52           77.22      458.7          0.08013
#
# ...

# %%
X_test
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 204        12.47         18.60           81.09      481.9          0.09965
# 70         18.94         21.31          123.60     1130.0          0.09009
# 131        15.46         19.48          101.70      748.9          0.10920
# 431        12.40         17.68           81.47      467.8          0.10540
# 540        11.54         14.44           74.65      402.9          0.09984
# ..           ...           ...             ...        ...              ...
# 486        14.64         16.85           94.21      666.0          0.08641
# 75         16.07         19.65          104.10      817.7          0.09168
# 249        11.52         14.93           73.87      406.3          0.10130
# 238        14.22         27.85           92.55      623.9          0.08223
# 265        20.73         31.12          135.70     1419.0          0.09469
#
# ...

# %% [markdown]
# ## **Model Training**

# %% [markdown]
# ### **Using TensorFlow Keras for Neural Networks**

# %% [markdown]
# ### **import libraries**

# %%
import tensorflow as tf

model = tf.keras.models.Sequential()

# %% [markdown]
# ### **Add layers to Model**

# %%
model.add(tf.keras.layers.Dense(256, input_shape=(X_train.shape[1],), activation='sigmoid'))
model.add(tf.keras.layers.Dense(256, activation='sigmoid'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### **model compilation**

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

y_train = y_train.astype('float32')
y_test = y_test.astype('float32')

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=1000, validation_data=(X_test, y_test))
# Out:
# Epoch 1/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9631 - loss: 0.0875 - val_accuracy: 0.9386 - val_loss: 0.1441
# Epoch 2/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9684 - loss: 0.0834 - val_accuracy: 0.9561 - val_loss: 0.0791
# Epoch 3/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9737 - loss: 0.0743 - val_accuracy: 0.9737 - val_loss: 0.0776
# Epoch 4/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9661 - loss: 0.1063 - val_accuracy: 0.9561 - val_loss: 0.1193
# Epoch 5/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9691 - loss: 0.1030 - val_accuracy: 0.9649 - val_loss: 0.1138
# Epoch 6/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9661 - loss: 0.0972 - val_accuracy: 0.9561 - val_loss: 0.1376
# Epoch 7/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9690 - loss: 0.1001 - val_accuracy: 0.9561 - val_loss: 0.0860
# Epoch 8/1000
# ...

# %% [markdown]
# ### **Evaluate Algorithm**

# %%
model.evaluate(x_test, y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9467 - loss: 0.1301
# [0.13196878135204315, 0.9473684430122375]
